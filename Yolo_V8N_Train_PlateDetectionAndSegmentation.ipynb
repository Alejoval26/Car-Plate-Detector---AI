# %% [markdown]
# #**Installing RoboFlow and Ultralitycs**

# %%
# !pip install roboflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 17.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
#     Uninstalling opencv-python-headless-4.8.1.78:
#       Successfully uninstalled opencv-python-headless-4.8.1.78
# ...

# %%
# !pip install ultralytics==8.0.196
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 kB 4.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# #**Adding the libraries to use**

# %%
from ultralytics import YOLO
import ultralytics
ultralytics.checks()
from IPython.display import display, Image
from roboflow import Roboflow
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.9/78.2 GB disk)

# %% [markdown]
# #**Accesing to the Dataset**

# %% [markdown]
# This lines of code is used for integrating with the Roboflow platform, a service that helps in building and deploying computer vision models.

# %%
#This line creates an instance of the Roboflow class. It is initialized with an API key, which is a unique identifier used to authenticate your access to the Roboflow services
rf = Roboflow(api_key="4urxYcvhvIhvHL1JxCv0")
#This line fetches a specific project within a workspace from my Roboflow account. The workspace("visionclass1") method selects the workspace named "visionclass1", and project("placas-tbtwc") selects the project named "placas-tbtwc" within that workspace
project = rf.workspace("visionclass1").project("placas-tbtwc")
#This final part accesses a specific version of the project (in this case, version 1) and downloads it in a format compatible with the YOLOv8 model architecture.
dataset = project.version(1).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Placas-1 in yolov8:: 100%|██████████| 2016/2016 [00:00<00:00, 4063.04it/s]

# %% [markdown]
# #**Setting up and running a training session for a YOLO-based segmentation model**

# %%
#This line sets a variable named HOME with the value "/content". In this context, "/content" is a directory path in the environment where the notebook is running.
HOME="/content"
#It changes the current working directory of the notebook to the directory specified by the HOME variable. In this case, it changes to the /content directory
# %cd {HOME}

'''
- yolo: This is likely a command-line interface (CLI) tool or a script for training YOLO models. YOLO (You Only Look Once) is a popular machine learning model for object detection tasks in computer vision.

- task=segment: This specifies the task for the YOLO model. In this case, the model is being trained for image segmentation and detection tasks.

- mode=train: Sets the mode of operation to train, indicating that the YOLO model will be trained.

- model=yolov8n-seg.pt: Specifies the model file to be used. Here, yolov8n-seg.pt is likely a pre-trained model file or a model architecture definition for YOLOv8 designed for segmentation tasks.

- data=/content/Placas-1/data.yaml: Specifies the path to the dataset configuration file. This file (data.yaml) contains information about the training and validation datasets, classes.

- epochs=50: Sets the number of training epochs.

- imgsz=640: Sets the image size (in pixels) for training the model. In this case, images will be resized to 640x640 pixels during training.
'''
# !yolo task=segment mode=train model=yolov8n-seg.pt  data=/content/Placas-1/data.yaml epochs=50 imgsz=640
# Out:
# /content
# ...
# 100% 6.73M/6.73M [00:00<00:00, 81.4MB/s]
# New https://pypi.org/project/ultralytics/8.0.209 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# **Once the training is finished, the best.pt file with the already trained model will be in the temporary colab files. In this case it was downloaded and then used in a local environment**

# %% [markdown]
# #**Confussion Matrix**

# %%
#changing the working directory and displaying an image file
# %cd {HOME}
Image(filename=f'{HOME}/runs/segment/train/confusion_matrix.png', width=600)
# Out:
# /content
